# %%
import h5py
import numpy as np
import pandas as pd
from astropy.time import Time
from tqdm import tqdm
import os
import vaex

# %%
from pyarrow import fs

# %%
s3 = fs.S3FileSystem(region='us-west-2')

# %%
testdf = vaex.open('s3://geostacks/testAtl/*/*/*parquet')

# %%
testdf[5000:5010]
# Out:
#   #       id       lat      lon      slope_y       slope_x    slope_x_sigma     h_li        s_li    q_flag    s_fg    snr      h_rb    bsnow_conf    cloud_flg_asr    cloud_flg_atm    msw_flag    fbsnow_h    bsnow_od    layer_flag    bckgrd    e_bckgrd    n_fit_photons    w_surface_window_final  t_year                      track                   midx            x        y    shards    cycle
#   0  1443432  -78.9803  86.3261  0.000345051  -0.00160603       0.000596048  3722.01  0.00926715         0       0      0  0.142379             6                2                1           4     59.9585   0.0925291             1   43147.9           0              441                         3  2019-05-06 11:24:41.283182  gt1l     2112221322433131312  1.19482e+06  76719.9   2112221        3
# ...

# %%
testdf.export_partitioned('./test/{subdir}/atl06.parquet', by=['shards','cycle'])
# Out:
# ERROR:MainThread:vaex.execution:error in task, flush task queue
# Traceback (most recent call last):
#   File "/home/jupyter/iceDivides/_build/pip_packages/lib/python3.8/site-packages/vaex/execution.py", line 176, in execute_async
#     task._parts = [encoding.decode('task-part-cpu', spec, df=run.df) for i in range(self.thread_pool.nthreads)]
#   File "/home/jupyter/iceDivides/_build/pip_packages/lib/python3.8/site-packages/vaex/execution.py", line 176, in <listcomp>
#     task._parts = [encoding.decode('task-part-cpu', spec, df=run.df) for i in range(self.thread_pool.nthreads)]
#   File "/home/jupyter/iceDivides/_build/pip_packages/lib/python3.8/site-packages/vaex/encoding.py", line 449, in decode
#     decoded = self.registry[typename].decode(self, value, **kwargs)
#   File "/home/jupyter/iceDivides/_build/pip_packages/lib/python3.8/site-packages/vaex/cpu.py", line 38, in decode
#     return cls.decode(encoding, spec, df)
# ...
