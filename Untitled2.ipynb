# %%
import vaex

# %%
df = vaex.open('./atl06_02_11.arrow')

# %%
df
# Out:
# #            id       lat                 lon                  slope_y                 slope_x                slope_x_sigma          h_li                 s_li                  q_flag    s_fg    snr    h_rb                 bsnow_conf    cloud_flg_asr    cloud_flg_atm    msw_flag    fbsnow_h            bsnow_od             layer_flag    bckgrd           e_bckgrd      n_fit_photons    w_surface_window_final    t_year                      cycle    track    x                    y
# 0            1443587  -79.00604150693235  176.34489505559952   0.0034970236010849476   0.045052722096443176   0.0008298112079501152  -19.586994171142578  0.012193245813250542  0         0       0.0    0.1700313538312912   -1            2                1                3           29.979246139526367  0.26861944794654846  1             28285.419921875  0.0           522              3.0                       2019-03-29 07:13:52.971019  2        gt1l     76147.62450344954    -1192036.1950727522
# ...

# %%
df['slope']=((df.slope_x**2 + df.slope_y**2)**0.5)*100

# %%
df.select(df.q_flag == 0, name='good')
sub1 = df.filter('good')
sub1.select(sub1.slope < 0.1, name='flat')
sub2 = sub1.filter('flat')

# %%
sub2
# Out:
# /home/jupyter/iceDivides/_build/pip_packages/lib/python3.8/site-packages/vaex/arrow/numpy_dispatch.py:72: RuntimeWarning: overflow encountered in square
#   result_data = op['op'](a_data, b_data)
# #           id       lat                 lon                  slope_y                  slope_x                  slope_x_sigma           h_li                s_li                  q_flag    s_fg    snr    h_rb                 bsnow_conf    cloud_flg_asr    cloud_flg_atm    msw_flag    fbsnow_h            bsnow_od             layer_flag    bckgrd        e_bckgrd      n_fit_photons    w_surface_window_final    t_year                      cycle    track    x                    y                   slope
# ...

# %%
#slope = np.sqrt(df.slope_x**2 + df.slope_y**2)
xy_mean_v = sub2.min(sub2.slope, binby=[sub2.x, sub2.y], 
                    #limits=[ [float(sub2.y.max()), 0], [float(sub2.x.min()), float(sub2.x.max())]], 
                    shape=(500, 500))
xy_mean_v
# Out:
# array([[inf, inf, inf, ..., inf, inf, inf],
#        [inf, inf, inf, ..., inf, inf, inf],
#        [inf, inf, inf, ..., inf, inf, inf],
#        ...,
#        [inf, inf, inf, ..., inf, inf, inf],
#        [inf, inf, inf, ..., inf, inf, inf],
#        [inf, inf, inf, ..., inf, inf, inf]], dtype=float32)

# %%
np.shape(xy_mean_v)
# Out:
# (250, 500)

# %%
df.

# %%
#slope = np.sqrt(df.slope_x**2 + df.slope_y**2)
sub2.plot2d_contour(sub2.x, sub2.y, sub2.slope)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-37e4099fc1ab> in <module>
#       1 #slope = np.sqrt(df.slope_x**2 + df.slope_y**2)
# ----> 2 sub2.plot2d_contour(sub2.x, sub2.y, sub2.slope)
#
# /home/jupyter/iceDivides/_build/pip_packages/lib/python3.8/site-packages/vaex/viz/contour.py in plot2d_contour(self, x, y, what, limits, shape, selection, f, figsize, xlabel, ylabel, aspect, levels, fill, colorbar, colorbar_label, colormap, colors, linewidths, linestyles, vmin, vmax, grid, show, **kwargs)
#      41
#      42     # Get the function out of the string
# ---> 43     f = vaex.dataset._parse_f(f)
#      44
#      45     # Internals on what to bin
#
# AttributeError: module 'vaex.dataset' has no attribute '_parse_f'

# %%
#slope = np.sqrt(df.slope_x**2 + df.slope_y**2)
xy_mean_v = sub2.min(sub2.y, binby=[sub2.y, sub2.x], 
                    #limits=[ [float(sub2.y.max()), 0], [float(sub2.x.min()), float(sub2.x.max())]], 
                    shape=(1500, 1500))
xy_mean_v
imshow(xy_mean_v)
colorbar()

# %%
#slope = np.sqrt(df.slope_x**2 + df.slope_y**2)
xy_mean_v = sub2.min(sub2.slope, binby=[sub2.x, sub2.y], 
                    limits=[ [float(sub2.y.max()), 0], [float(sub2.x.min()), float(sub2.x.max())]], 
                    shape=(500, 500))
xy_mean_v
imshow(xy_mean_v)
colorbar()

# %%
imshow(xy_mean_v)
colorbar()

# %%
sub = df.slope < 0.001

# %%
type(sub)
# Out:
# vaex.expression.Expression

# %%
# Fixing figure output for all figures
rcParams['axes.labelsize'] = 9
rcParams['xtick.labelsize'] = 9
rcParams['ytick.labelsize'] = 9
rcParams['legend.fontsize'] = 9
rcParams['figure.dpi'] = 160
rcParams['savefig.dpi'] = 200

# %%
xycounts = df.count(binby=[df.x, df.y], limits=[[-1000*1000, 0], [1000*1000, 200*1000]], shape=(100, 100))
xycounts
# Out:
# array([[     0,      0,      0, ...,  19163,  21707,  23319],
#        [     0,      0,      0, ...,  19647,  22343,  22304],
#        [     0,      0,      0, ...,  19025,  19414,  22189],
#        ...,
#        [ 26542,  24864,  22493, ..., 630677, 446818,    353],
#        [ 29063,  28760,  29477, ..., 656427, 372070,      0],
#        [ 29134,  29402,  30323, ..., 673544, 332813,      0]])

# %%
imshow(xycounts)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
