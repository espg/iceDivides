# %%
import h5py
import numpy as np
import pandas as pd
from astropy.time import Time
from tqdm import tqdm
import os
import vaex

# %%
shards = ['s3://geostacks/icesat2/shards=5121311/cycle=3/atl06.parquet',
          's3://geostacks/icesat2/shards=5121312/cycle=3/atl06.parquet',
          's3://geostacks/icesat2/shards=5121312/cycle=3/atl06.parquet',
          's3://geostacks/icesat2/shards=5121321/cycle=3/atl06.parquet']

# %%
# %%time
testdf = vaex.open_many(shards)
# Out:
# CPU times: user 737 ms, sys: 43.8 ms, total: 781 ms
# Wall time: 7.02 s

# %%
len(testdf)
# Out:
# 1577565

# %%
testdf
# Out:
# #          id       lat                 lon                  slope_y                 slope_x                 slope_x_sigma           h_li                    s_li                    q_flag    s_fg    snr                     h_rb                    bsnow_conf    cloud_flg_asr    cloud_flg_atm    msw_flag    fbsnow_h                bsnow_od                layer_flag    bckgrd            e_bckgrd                n_fit_photons    w_surface_window_final    t_year                      track    midx                 x                    y                   shards    cycle
# ...

# %%
for key in testdf:
    print((key, testdf[key].data_type()))
# Out:
# ('id', int32)
# ('lat', float64)
# ('lon', float64)
# ('slope_y', float32)
# ('slope_x', float32)
# ('slope_x_sigma', float32)
# ('h_li', float32)
# ('s_li', float32)
# ('q_flag', int8)
# ('s_fg', int8)
# ('snr', float32)
# ('h_rb', float32)
# ('bsnow_conf', int8)
# ('cloud_flg_asr', int8)
# ('cloud_flg_atm', int8)
# ('msw_flag', int8)
# ('fbsnow_h', float32)
# ('bsnow_od', float32)
# ('layer_flag', int8)
# ('bckgrd', float32)
# ('e_bckgrd', float32)
# ('n_fit_photons', int32)
# ('w_surface_window_final', float32)
# ('t_year', datetime64[ns])
# ('track', string)
# ('midx', int64)
# ('x', float64)
# ('y', float64)
# ('shards', dictionary<values=int64, indices=int32, ordered=0>)
# ('cycle', dictionary<values=int64, indices=int32, ordered=0>)

# %%
testdf
# Out:
# #       id       lat                 lon                  slope_y                  slope_x                 slope_x_sigma          h_li                s_li                  q_flag    s_fg    snr    h_rb                 bsnow_conf    cloud_flg_asr    cloud_flg_atm    msw_flag    fbsnow_h                bsnow_od                layer_flag    bckgrd          e_bckgrd    n_fit_photons    w_surface_window_final    t_year                      track    midx                 x                    y                   shards    cycle
# ...
